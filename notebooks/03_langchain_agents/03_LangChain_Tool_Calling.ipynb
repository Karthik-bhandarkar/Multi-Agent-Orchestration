# %%
#!pip uninstall -y pydantic pydantic-core
# !pip install -q pydantic==1.10.12
# !pip install -q langchain==0.1.20 langchain-groq==0.1.3
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.3/149.3 kB 1.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.4/158.4 kB 3.4 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.3.8 requires pydantic<3.0.0,>=2.0.0, but you have pydantic 1.10.12 which is incompatible.
# mcp 1.21.0 requires pydantic<3.0.0,>=2.11.0, but you have pydantic 1.10.12 which is incompatible.
# google-genai 1.49.0 requires pydantic<3.0.0,>=2.9.0, but you have pydantic 1.10.12 which is incompatible.
# pydantic-settings 2.12.0 requires pydantic>=2.7.0, but you have pydantic 1.10.12 which is incompatible.
# albumentations 2.0.8 requires pydantic>=2.9.2, but you have pydantic 1.10.12 which is incompatible.
# langchain-core 0.3.79 requires pydantic<3.0.0,>=2.7.4, but you have pydantic 1.10.12 which is incompatible.
# ...
